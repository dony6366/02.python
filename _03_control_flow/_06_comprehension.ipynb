# %% [markdown]
# # Comprehension 내포(함축)
#
# - Comprehension은 한 줄짜리 반복문으로 새로운 컬렉션을 만드는 문법이다.
# - 대표적으로 list comprehension과 dict comprehension이 있다.
# - 반복문으로 값을 하나씩 추가하는 패턴을 더 짧고 읽기 좋게 표현할 수 있다.
#
# - list comprehension
# ```
# # list 생성
# [표현식 for 변수 in 반복가능한객체]
#
# # 조건 포함
# [표현식 for 변수 in 반복가능한객체 if 조건식]
# ```
#
# - dict comprehension
# ```
# # dict 생성
# {key표현식: value표현식 for 변수 in 반복가능한객체}
#
# # 조건 포함
# {key표현식: value표현식 for 변수 in 반복가능한객체 if 조건식}
# ```

# %% [markdown]
# ## 1. for 반복문과 list comprehension 비교
#
# 먼저 일반 `for` 반복문으로 리스트를 만든 뒤, 같은 결과를 list comprehension으로 바꿔 본다.

# %%
from prompt_toolkit.key_binding.bindings.named_commands import print_last_kbd_macro


def make_numbers_with_for()->list[int]:
    numbers = []
    for n in range(1,6):
        numbers.append(n)
    return numbers
print(make_numbers_with_for())

#list comprehension
def make_numbers_with_comprehension()->list[int]:
    return [n*2 for n in range(1,6)]
print(make_numbers_with_comprehension())
# Out:
# [1, 2, 3, 4, 5]
# [2, 4, 6, 8, 10]

# %% [markdown]
# ## 2. 조건식이 있는 list comprehension
#
# `if` 조건을 붙이면 원하는 요소만 필터링해서 리스트를 만들 수 있다.

# %%
# 1~100 사이 정수중 3의 배수만 골라서 list요소로 추가
def make_numbers3() -> list[int]:
    return [n for n in range(1,101) if n % 3 == 0 ]
print('3의 배수 lis: ',make_numbers3())
# Out:
# 3의 배수 lis:  [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99]

# %%
# 전달된 list에서 장수(int) 타입만 필터링해서 반환
lst = [1,'123','안녕',22, {},[], True, 333]

# object]타입 : 아무타입이나 가능(==Any)
def filter_int_valuse(valuse: list[object])->list[int]:
# isinstance(valuw, type) -> bool
# - value의 자료형이 type과 일치하면 True, 아니면 False
    return  [v for v in valuse if isinstance(v,int)]

print(filter_int_valuse(lst))
# Out:
# [1, 22, True, 333]

# %% [markdown]
# ## 3. 중첩 반복문 list comprehension
#
# 반복문이 중첩된 구조도 comprehension으로 표현할 수 있다. 다만 너무 복잡해지면 일반 반복문이 더 읽기 쉽다.

# %%
# 중첩 반복문
def make_positions() -> list[tuple[int,int]]:
    positions = list[tuple[int,int]] = []

    for row in range(3):
        for col in range(5):
            positions.append((row,col))

    return positions

print(make_positions())


    # positions.append((1,1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 11
#       7             positions.append((row,col))
#       8
#       9     return positions
#      10
# ---> 11 print(make_positions())
#      12
#      13
#      14     # positions.append((1,1))
#
# Cell In[23], line 3, in make_positions()
#       2 def make_positions() -> list[tuple[int,int]]:
# ----> 3     positions = list[tuple[int,int]] = []
#       4
#       5     for row in range(3):
#       6         for col in range(5):
#
# TypeError: 'type' object does not support item assignment

# %%
# 중첩 comprehension
def make_positions_with_comprehension() -> list[tuple[int,int]]:
    return  [(row, col)for row in range(3) for col in range(5)]
print(make_positions_with_comprehension())
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (0, 4), (1, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 0), (2, 1), (2, 2), (2, 3), (2, 4)]

# %% [markdown]
# ## 4. dict comprehension
#
# `dict`도 comprehension으로 만들 수 있다.
#
# ```python
# {key식: value식 for 요소 in iterable}
# ```

# %%
def make_squar_map() -> dict[int,int]:
    return {k:k ** 2 for k in range(1,6)}
print(make_squar_map())
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# 문자열 리스트를 전달하여  {"문자열" : 문자열 길이" 형태의 list[dict] 반환
def make_word_length_map(words : list[str]) -> dict[str,int]:
    # 일반적인 방법
   # result = {}
   # for word in words:
   #     result[word] = len(word)
   # return result

   #comprehension
   return {word : len(word) for word in words if len(word) > 3}
words = [ 'hi','hello', 'world', '집가고 싶다', '살려주세요' ]
print(make_word_length_map(words))
# Out:
# {'hello': 5, 'world': 5, '집가고 싶다': 6, '살려주세요': 5}

# %% [markdown]
# ## 5. list와 dict 변환
#
# `zip()`과 `dict()`를 함께 사용하면 두 리스트를 하나의 딕셔너리로 묶을 수 있다. 반대로 `dict.items()`와 unpacking을 사용하면 딕셔너리에서 key와 value 묶음을 분리할 수 있다.

# %%
def makr_age_map() -> dict[str,int]:
    names: list[str] = ["홍길동",'아무개', '이순신']
    ages: list[int] = [20, 40, 30]

    # zip(names,ages) == ['홍길동', 20, '아무개', 40, '이순신', 30]
    return dict(zip(names,ages))

print("list -> dict: ", makr_age_map())
# Out:
# list -> dict:  {'홍길동': 20, '아무개': 40, '이순신': 30}

# %%
def split_age_map()-> tuple[tuple[str,...], tuple[int,...]]:
    info: dict [str,int] = {'홍길동': 20, '아무개': 40, '이순신': 30}
    print("info.items(): ", info.items())
    print(*info.items())

    names, ages = zip(*info.items())
    return names, ages


print("dict -> tuple 묶음: ", split_age_map())
# Out:
# info.items():  dict_items([('홍길동', 20), ('아무개', 40), ('이순신', 30)])
# ('홍길동', 20) ('아무개', 40) ('이순신', 30)
# dict -> tuple 묶음:  (('홍길동', '아무개', '이순신'), (20, 40, 30))
